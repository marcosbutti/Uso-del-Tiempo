# %% [markdown]
# ### Encuesta Nacional de Uso del Tiempo 2021 (Indec)
#
#     ID   Clave de identificación del hogar
#     N_MIEMBRO   Nº de componente
#     N_FILA   Número de fila del diario de actividades
#     ACTIVIDAD_HORA   Hora/s del diario de actividades
#     ACTIVIDAD_MINUTO   Minuto/s del diario de actividades
#
# ##### Código de actividad:
#     11 Trabajar en una ocupación
#     12 Realizar una pasantía no remunerada
#     13 Buscar trabajo o iniciar un negocio
#     14 Viajar para ir y volver del trabajo
#     2 Trabajar para consumo propio del hogar
#     31 Preparar y servir la comida
#     32 Limpiar la vivienda
#     33 Lavar, planchar o arreglar la ropa/calzado
#     34 Reparar y mantener la vivienda o los bienes del hogar
#     35 Hacer pagos y trámites del hogar
#     36 Hacer compras para el hogar
#     37 Cuidar mascotas y plantas
#     411 Cuidados personales y apoyo a miembros del hogar de 0 a 13 años
#     412 Cuidado temporal de salud a miembros del hogar de 0 a 13 años
#     413 Apoyo escolar a miembros del hogar de 0 a 13 años
#     414 Acompañamiento y traslados de miembros del hogar de 0 a 13 años
#     419 Otras actividades de cuidado y apoyo a miembros del hogar de 0 a 13 años
#     421 Cuidados personales y apoyo a miembros del hogar de 14 a 64 años
#     422 Cuidado temporal de salud a miembros del hogar de 14 a 64 años
#     423 Acompañamiento y traslados a miembros del hogar de 14 a 64 años
#     429 Otras actividades de cuidado y apoyo a miembros del hogar de 14 a 64 años
#     431 Cuidados personales y apoyo a miembros del hogar de 65 años y más
#     432 Cuidado temporal de salud a miembros del hogar de 65 años y más
#     433 Acompañamiento y traslados a miembros del hogar de 65 años y más
#     439 Otras actividades de cuidado y apoyo a miembros del hogar de 65 años y más
#     441 Cuidados personales y apoyo a miembros del hogar con discapacidad o dependencia permanente
#     442 Cuidado de salud a miembros del hogar con discapacidad
#     443 Acompañamiento y traslado a algún lugar a miembros del hogar con discapacidad
#     449 Otras actividades de cuidado a miembros del hogar con discapacidad
#     52 Hacer trabajo voluntario para la comunidad
#     53 Hacer trabajo voluntario en instituciones sin fines de lucro
#     54 Ayudar a otros hogares familiares sin pago
#     55 Ayudar a otros hogares no familiares sin pago
#     61 Estudiar
#     62 Viajar para estudiar
#     711 Reunirse con familiares o amigos
#     712 Participar de celebraciones comunitarias, políticas o religiosas
#     72 Asistir a eventos o espectáculos
#     73 Realizar actividades artísticas, juegos o entretenimientos
#     74 Hacer deportes o ejercicio físico
#     81 Leer libros o revistas
#     82 Ver televisión, videos o transmisiones en vivo
#     83 Escuchar música o radio
#     84 Usar computadora o tableta
#     85 Usar el celular
#     911 Higienizarse o arreglarse
#     912 Cuidar su salud o hacer terapias y tratamientos
#     914 Viajar para cuidar su salud
#     921 Comer y beber
#     922 Dormir
#     999 ns/nc
#     923 Descansar, rezar o meditar u otras actividades personales

# %%
import pandas as pd
import numpy as np

data = pd.read_table("enut2021_diario.txt", sep="|")
data
# Out:
#              ID  N_MIEMBRO  N_FILA  ACTIVIDAD_HORA  ACTIVIDAD_MINUTO  \
# 0        138453          2      56               9                10
# 1        138453          2      57               9                20
# 2        138453          2      58               9                30
# 3        138453          2      59               9                40
# 4        138453          2      60               9                50
# ...         ...        ...     ...             ...               ...
# 2066395  104079          1      99              16                20
# 2066396  104079          1     100              16                30
# 2066397  104079          1     101              16                40
# 2066398  104079          1     102              16                50
# 2066399  104079          1     103              17                 0
#
#          ACTIVIDAD_1  ACTIVIDAD_2  ACTIVIDAD_3
# 0              911.0        411.0          NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2066400 entries, 0 to 2066399
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   ID                int64
#  1   N_MIEMBRO         int64
#  2   N_FILA            int64
#  3   ACTIVIDAD_HORA    int64
#  4   ACTIVIDAD_MINUTO  int64
#  5   ACTIVIDAD_1       float64
#  6   ACTIVIDAD_2       float64
#  7   ACTIVIDAD_3       float64
# dtypes: float64(3), int64(5)
# memory usage: 126.1 MB

# %%
data.isnull().sum()  #Cantidad de Nulos por columna
# Out:
# ID                        0
# N_MIEMBRO                 0
# N_FILA                    0
# ACTIVIDAD_HORA            0
# ACTIVIDAD_MINUTO          0
# ACTIVIDAD_1             766
# ACTIVIDAD_2         1749215
# ACTIVIDAD_3         2033103
# dtype: int64

# %%
#Reemplazo los nulos con 999 = no sabe/no contesta para manejar de forma numérica más simple
data = data.fillna(999)
data
# Out:
#              ID  N_MIEMBRO  N_FILA  ACTIVIDAD_HORA  ACTIVIDAD_MINUTO  \
# 0        138453          2      56               9                10
# 1        138453          2      57               9                20
# 2        138453          2      58               9                30
# 3        138453          2      59               9                40
# 4        138453          2      60               9                50
# ...         ...        ...     ...             ...               ...
# 2066395  104079          1      99              16                20
# 2066396  104079          1     100              16                30
# 2066397  104079          1     101              16                40
# 2066398  104079          1     102              16                50
# 2066399  104079          1     103              17                 0
#
#          ACTIVIDAD_1  ACTIVIDAD_2  ACTIVIDAD_3
# 0              911.0        411.0        999.0
# ...

# %%
data["ACTIVIDAD_1"] = data["ACTIVIDAD_1"].astype("int64")  #Transformamos a entero los num flotantes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2066400 entries, 0 to 2066399
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   ID                int64
#  1   N_MIEMBRO         int64
#  2   N_FILA            int64
#  3   ACTIVIDAD_HORA    int64
#  4   ACTIVIDAD_MINUTO  int64
#  5   ACTIVIDAD_1       int64
#  6   ACTIVIDAD_2       float64
#  7   ACTIVIDAD_3       float64
# dtypes: float64(2), int64(6)
# memory usage: 126.1 MB

# %%
data["ACTIVIDAD_2"] = data["ACTIVIDAD_2"].astype("int64")
data["ACTIVIDAD_3"] = data["ACTIVIDAD_3"].astype("int64")
data.head()
# Out:
#        ID  N_MIEMBRO  N_FILA  ACTIVIDAD_HORA  ACTIVIDAD_MINUTO  ACTIVIDAD_1  \
# 0  138453          2      56               9                10          911
# 1  138453          2      57               9                20          921
# 2  138453          2      58               9                30          921
# 3  138453          2      59               9                40          921
# 4  138453          2      60               9                50          921
#
#    ACTIVIDAD_2  ACTIVIDAD_3
# 0          411          999
# 1          411          999
# 2          411          999
# 3          411          999
# 4          411          999

# %%
Act1 = data.groupby(data.ACTIVIDAD_1).count().sort_values("ID",ascending=False)
Act1.head(5)
#Como primer actividad las que más aparecen son: dormir, trabajar, comer y beber, 
#ver televisión, videos o transmisiones en vivo, reunirse con familiares o amigos...
# Out:
#                  ID  N_MIEMBRO  N_FILA  ACTIVIDAD_HORA  ACTIVIDAD_MINUTO  \
# ACTIVIDAD_1
# 922          741814     741814  741814          741814            741814
# 11           279232     279232  279232          279232            279232
# 921          170209     170209  170209          170209            170209
# 82           129725     129725  129725          129725            129725
# 711          107353     107353  107353          107353            107353
#
#              ACTIVIDAD_2  ACTIVIDAD_3
# ACTIVIDAD_1
# 922               741814       741814
# 11                279232       279232
# 921               170209       170209
# 82                129725       129725
# 711               107353       107353

# %%
Act2 = data.groupby(data.ACTIVIDAD_2).count().sort_values("ID",ascending=False)
Act2.head(5)
#Como segunda actividad cambia cuales son las más comunes.
# Out:
#                   ID  N_MIEMBRO   N_FILA  ACTIVIDAD_HORA  ACTIVIDAD_MINUTO  \
# ACTIVIDAD_2
# 999          1749273    1749273  1749273         1749273           1749273
# 82             69354      69354    69354           69354             69354
# 83             43374      43374    43374           43374             43374
# 85             40500      40500    40500           40500             40500
# 411            39539      39539    39539           39539             39539
#
#              ACTIVIDAD_1  ACTIVIDAD_3
# ACTIVIDAD_2
# 999              1749273      1749273
# 82                 69354        69354
# 83                 43374        43374
# 85                 40500        40500
# 411                39539        39539

# %%
Act3 = data.groupby(data.ACTIVIDAD_3).count().sort_values("ID",ascending=False)
Act3.head(5)
#Como tercer actividad también cambia pero predomina NoSabe/NoContesta
# Out:
#                   ID  N_MIEMBRO   N_FILA  ACTIVIDAD_HORA  ACTIVIDAD_MINUTO  \
# ACTIVIDAD_3
# 999          2033104    2033104  2033104         2033104           2033104
# 411             6572       6572     6572            6572              6572
# 85              6068       6068     6068            6068              6068
# 82              4723       4723     4723            4723              4723
# 921             3654       3654     3654            3654              3654
#
#              ACTIVIDAD_1  ACTIVIDAD_2
# ACTIVIDAD_3
# 999              2033104      2033104
# 411                 6572         6572
# 85                  6068         6068
# 82                  4723         4723
# 921                 3654         3654

# %%
#Cuanto duermen
dormir = data.loc[(data["ACTIVIDAD_1"] == 922)]
dormir
# Out:
#              ID  N_MIEMBRO  N_FILA  ACTIVIDAD_HORA  ACTIVIDAD_MINUTO  \
# 62       182814          2      33               5                20
# 63       182814          2      34               5                30
# 64       182814          2      35               5                40
# 65       182814          2      36               5                50
# 66       182814          2      37               6                 0
# ...         ...        ...     ...             ...               ...
# 2066385  104079          1      89              14                40
# 2066386  104079          1      90              14                50
# 2066387  104079          1      91              15                 0
# 2066388  104079          1      92              15                10
# 2066389  104079          1      93              15                20
#
#          ACTIVIDAD_1  ACTIVIDAD_2  ACTIVIDAD_3
# 62               922          999          999
# ...

# %%
tiempodormir = dormir.groupby(['ID', 'N_MIEMBRO']).size().reset_index(name='tiempo')
tiempodormir
# Out:
#            ID  N_MIEMBRO  tiempo
# 0      100000          1     103
# 1      100001          1      72
# 2      100012          1      63
# 3      100014          3      54
# 4      100021          2      54
# ...       ...        ...     ...
# 14297  199975          2      55
# 14298  199983          9      36
# 14299  199989          1      57
# 14300  199990          2      70
# 14301  200000          1      48
#
# [14302 rows x 3 columns]

# %%
tiempodormir["tiempo"] = tiempodormir["tiempo"]*1/6  #Se transforman los bloques de 10 minutos en horas.
tiempodormir
# Out:
#            ID  N_MIEMBRO     tiempo
# 0      100000          1  17.166667
# 1      100001          1  12.000000
# 2      100012          1  10.500000
# 3      100014          3   9.000000
# 4      100021          2   9.000000
# ...       ...        ...        ...
# 14297  199975          2   9.166667
# 14298  199983          9   6.000000
# 14299  199989          1   9.500000
# 14300  199990          2  11.666667
# 14301  200000          1   8.000000
#
# [14302 rows x 3 columns]

# %%
promdormir = tiempodormir["tiempo"].mean()
promdormir
# Out:
# 8.644641775043118

# %%
import matplotlib.pyplot as plt

# %%
# Graficar los conteos
plt.figure(figsize=(18,9))
plt.scatter(tiempodormir["ID"], tiempodormir['tiempo'], marker=".")

# Trazar la línea con el promedio
plt.axhline(y=promdormir, color='red', linestyle='--',linewidth=2)
plt.text(200000,promdormir + 0.5, "Promedio", color='red', fontsize=12,backgroundcolor="white")
plt.text(96000,promdormir,round(promdormir,2), color="red", fontsize=12)
plt.xlim(99000,plt.xlim()[1]) #Comienzo del eje X

# Configurar los títulos
plt.title("Tiempo de Dormir", fontsize=14, y=0.94)
plt.xlabel('ID')
plt.ylabel('Horas')

# Mostrar el gráfico
plt.show()

# %%
#Cuanto Trabajan
trabajar = data.loc[(data["ACTIVIDAD_1"] == 11)]
trabajar
# Out:
#              ID  N_MIEMBRO  N_FILA  ACTIVIDAD_HORA  ACTIVIDAD_MINUTO  \
# 55       102456          2      75              12                20
# 56       102456          2      76              12                30
# 57       102456          2      77              12                40
# 58       102456          2      78              12                50
# 59       102456          2      79              13                 0
# ...         ...        ...     ...             ...               ...
# 2066350  174993          2      89              14                40
# 2066351  174993          2      90              14                50
# 2066352  174993          2      91              15                 0
# 2066353  174993          2      92              15                10
# 2066354  174993          2      93              15                20
#
#          ACTIVIDAD_1  ACTIVIDAD_2  ACTIVIDAD_3
# 55                11          999          999
# ...

# %%
tiempotrabajo = trabajar.groupby(['ID', 'N_MIEMBRO']).size().reset_index(name='tiempo')
tiempotrabajo
# Out:
#           ID  N_MIEMBRO  tiempo
# 0     100012          1      48
# 1     100030          2      41
# 2     100032          2      18
# 3     100038          1      60
# 4     100057          3      47
# ...      ...        ...     ...
# 6193  199861          1      57
# 6194  199871          2      54
# 6195  199899          1      15
# 6196  199983          9      53
# 6197  200000          1      12
#
# [6198 rows x 3 columns]

# %%
tiempotrabajo["tiempo"] = tiempotrabajo["tiempo"]*1/6  #Se transforman los bloques de 10 minutos en horas.
tiempotrabajo
# Out:
#           ID  N_MIEMBRO     tiempo
# 0     100012          1   8.000000
# 1     100030          2   6.833333
# 2     100032          2   3.000000
# 3     100038          1  10.000000
# 4     100057          3   7.833333
# ...      ...        ...        ...
# 6193  199861          1   9.500000
# 6194  199871          2   9.000000
# 6195  199899          1   2.500000
# 6196  199983          9   8.833333
# 6197  200000          1   2.000000
#
# [6198 rows x 3 columns]

# %%
promtra = tiempotrabajo["tiempo"].mean()
promtra
# Out:
# 7.508658707109821

# %%
# Graficar los conteos
plt.figure(figsize=(18,9))
plt.scatter(tiempotrabajo["ID"], tiempotrabajo['tiempo'], marker=".", c="orange")

# Trazar la línea con el promedio
plt.axhline(y=promtra, color='red', linestyle='--',linewidth=2)
plt.text(200000,promtra + 0.5, "Promedio", color='red', fontsize=12,backgroundcolor="white")
plt.text(96000,promtra,round(promtra,2), color="red", fontsize=12)
plt.xlim(99000,plt.xlim()[1]) #Comienzo del eje X

# Configurar los títulos
plt.title("Tiempo Trabajando", fontsize=14, y=0.94)
plt.xlabel('ID')
plt.ylabel('Horas')

# Mostrar el gráfico
plt.show()

# %%
#Uso del Celular
usocel = data.loc[(data[["ACTIVIDAD_1","ACTIVIDAD_2","ACTIVIDAD_3"]] == 85).any(axis=1)]
usocel
# Out:
#              ID  N_MIEMBRO  N_FILA  ACTIVIDAD_HORA  ACTIVIDAD_MINUTO  \
# 429      151468          4      75              12                20
# 442      151468          4      88              14                30
# 451      151468          4      97              16                 0
# 525      182814          2     118              19                30
# 526      182814          2     119              19                40
# ...         ...        ...     ...             ...               ...
# 2066024  148993          2     137              22                40
# 2066025  148993          2     138              22                50
# 2066224  199814          4     130              21                30
# 2066225  199814          4     131              21                40
# 2066226  199814          4     132              21                50
#
#          ACTIVIDAD_1  ACTIVIDAD_2  ACTIVIDAD_3
# 429              921           82           85
# ...

# %%
tiempocel = usocel.groupby(['ID', 'N_MIEMBRO']).size().reset_index(name='tiempo')
tiempocel
# Out:
#           ID  N_MIEMBRO  tiempo
# 0     100014          3       9
# 1     100023          1      17
# 2     100030          2      15
# 3     100055          1       7
# 4     100057          3      24
# ...      ...        ...     ...
# 5734  199934          1      27
# 5735  199947          4       9
# 5736  199975          2      25
# 5737  199983          9      17
# 5738  199989          1       7
#
# [5739 rows x 3 columns]

# %%
tiempocel["tiempo"] = tiempocel["tiempo"]*1/6  #Se transforman los bloques de 10 minutos en horas.
tiempocel
# Out:
#           ID  N_MIEMBRO    tiempo
# 0     100014          3  1.500000
# 1     100023          1  2.833333
# 2     100030          2  2.500000
# 3     100055          1  1.166667
# 4     100057          3  4.000000
# ...      ...        ...       ...
# 5734  199934          1  4.500000
# 5735  199947          4  1.500000
# 5736  199975          2  4.166667
# 5737  199983          9  2.833333
# 5738  199989          1  1.166667
#
# [5739 rows x 3 columns]

# %%
promcel=tiempocel["tiempo"].mean()
promcel
# Out:
# 2.0053145147238194

# %%
# Graficar los conteos
plt.figure(figsize=(18,9))
plt.scatter(tiempocel["ID"], tiempocel['tiempo'], marker=".", c="green")

# Trazar la línea con el promedio
plt.axhline(y=promcel, color='red', linestyle='--',linewidth=2)
plt.text(200000,promcel + 0.5, " Promedio", color='red', fontsize=12,backgroundcolor="white")
plt.text(96000,promcel-0.2,round(promcel,2), color="red", fontsize=12)
plt.xlim(99000,plt.xlim()[1]) #Comienzo del eje X

# Configurar los títulos
plt.title("Tiempo de uso del Celular", fontsize=14, y=0.95)
plt.xlabel('ID')
plt.ylabel('Horas')

# Mostrar el gráfico
plt.show()

# %%
#Música
musica = data.loc[(data[["ACTIVIDAD_1","ACTIVIDAD_2","ACTIVIDAD_3"]] == 83).any(axis=1)]
musica
# Out:
#              ID  N_MIEMBRO  N_FILA  ACTIVIDAD_HORA  ACTIVIDAD_MINUTO  \
# 178      153890          1      44               7                10
# 179      153890          1      45               7                20
# 180      153890          1      46               7                30
# 181      153890          1      47               7                40
# 182      153890          1      48               7                50
# ...         ...        ...     ...             ...               ...
# 2066395  104079          1      99              16                20
# 2066396  104079          1     100              16                30
# 2066397  104079          1     101              16                40
# 2066398  104079          1     102              16                50
# 2066399  104079          1     103              17                 0
#
#          ACTIVIDAD_1  ACTIVIDAD_2  ACTIVIDAD_3
# 178              921           83          999
# ...

# %%
tiempomusica = musica.groupby(['ID', 'N_MIEMBRO']).size().reset_index(name='tiempo')
tiempomusica
# Out:
#           ID  N_MIEMBRO  tiempo
# 0     100055          1      12
# 1     100108          1      21
# 2     100110          1       4
# 3     100141          2      28
# 4     100151          1      11
# ...      ...        ...     ...
# 3480  199895          3       6
# 3481  199907          2      10
# 3482  199930          4      12
# 3483  199934          1       6
# 3484  199983          9      11
#
# [3485 rows x 3 columns]

# %%
tiempomusica["tiempo"] = tiempomusica["tiempo"]*1/6  #Se transforman los bloques de 10 minutos en horas.
tiempomusica
# Out:
#           ID  N_MIEMBRO    tiempo
# 0     100055          1  2.000000
# 1     100108          1  3.500000
# 2     100110          1  0.666667
# 3     100141          2  4.666667
# 4     100151          1  1.833333
# ...      ...        ...       ...
# 3480  199895          3  1.000000
# 3481  199907          2  1.666667
# 3482  199930          4  2.000000
# 3483  199934          1  1.000000
# 3484  199983          9  1.833333
#
# [3485 rows x 3 columns]

# %%
prom = tiempomusica["tiempo"].mean()
prom
# Out:
# 2.7548541367766624

# %%
# Graficar los conteos
plt.figure(figsize=(18,9))
plt.scatter(tiempomusica["ID"], tiempomusica['tiempo'], marker="p", c="purple")

# Trazar la línea con el promedio
plt.axhline(y=prom, color='red', linestyle='--',linewidth=2)
plt.text(200000,prom + 0.5, "Promedio", color='red', fontsize=12,backgroundcolor="white")
plt.text(96000,prom,round(prom,2), color="red", fontsize=12)
plt.xlim(99000,plt.xlim()[1]) #Comienzo del eje X

# Configurar los títulos
plt.title("Tiempo escuchando Música o Radio", fontsize=14, y=0.95)
plt.xlabel('ID')
plt.ylabel('Horas')

# Mostrar el gráfico
plt.show()

# %%
#Ver Televisión, Videos, vivo...
tv = data.loc[(data[["ACTIVIDAD_1","ACTIVIDAD_2","ACTIVIDAD_3"]] == 82).any(axis=1)]
tv
# Out:
#              ID  N_MIEMBRO  N_FILA  ACTIVIDAD_HORA  ACTIVIDAD_MINUTO  \
# 244      125713          1      91              15                 0
# 245      125713          1      92              15                10
# 246      125713          1      93              15                20
# 378      112855          2     127              21                 0
# 379      112855          2     128              21                10
# ...         ...        ...     ...             ...               ...
# 2066322  130545          1     140              23                10
# 2066323  130545          1     141              23                20
# 2066324  130545          1     142              23                30
# 2066325  130545          1     143              23                40
# 2066326  130545          1     144              23                50
#
#          ACTIVIDAD_1  ACTIVIDAD_2  ACTIVIDAD_3
# 244              921           82          999
# ...

# %%
tiempotv = tv.groupby(['ID', 'N_MIEMBRO']).size().reset_index(name='tiempo')
tiempotv
# Out:
#            ID  N_MIEMBRO  tiempo
# 0      100001          1      21
# 1      100012          1      15
# 2      100021          2       6
# 3      100023          1      12
# 4      100026          1      18
# ...       ...        ...     ...
# 10758  199975          2      21
# 10759  199983          9       3
# 10760  199989          1      10
# 10761  199990          2      21
# 10762  200000          1       6
#
# [10763 rows x 3 columns]

# %%
tiempotv["tiempo"] = tiempotv["tiempo"]*1/6  #Se transforman los bloques de 10 minutos en horas.
tiempotv
# Out:
#            ID  N_MIEMBRO    tiempo
# 0      100001          1  3.500000
# 1      100012          1  2.500000
# 2      100021          2  1.000000
# 3      100023          1  2.000000
# 4      100026          1  3.000000
# ...       ...        ...       ...
# 10758  199975          2  3.500000
# 10759  199983          9  0.500000
# 10760  199989          1  1.666667
# 10761  199990          2  3.500000
# 10762  200000          1  1.000000
#
# [10763 rows x 3 columns]

# %%
promtv = tiempotv["tiempo"].mean()
promtv
# Out:
# 3.155904487596395

# %%
# Graficar los conteos
plt.figure(figsize=(18,9))
plt.scatter(tiempotv["ID"], tiempotv['tiempo'], marker="h", c="dimgrey")

# Trazar la línea con el promedio
plt.axhline(y=promtv, color='red', linestyle='--',linewidth=2)
plt.text(200000,promtv + 0.5, "Promedio", color='red', fontsize=12, backgroundcolor="white")
plt.text(96000,promtv,round(promtv,2), color="red", fontsize=12)
plt.xlim(99000,plt.xlim()[1]) #Comienzo del eje X

# Configurar los títulos
plt.title("Tiempo viendo Televisión, Videos o Transmisiones en vivo", fontsize=14, y=0.95)
plt.xlabel('ID')
plt.ylabel('Horas')

# Mostrar el gráfico
plt.show()

# %%
#Familia y Amigos
flia = data.loc[(data[["ACTIVIDAD_1","ACTIVIDAD_2","ACTIVIDAD_3"]] == 711).any(axis=1)]
flia
# Out:
#              ID  N_MIEMBRO  N_FILA  ACTIVIDAD_HORA  ACTIVIDAD_MINUTO  \
# 439      151468          4      85              14                 0
# 440      151468          4      86              14                10
# 441      151468          4      87              14                20
# 442      151468          4      88              14                30
# 443      151468          4      89              14                40
# ...         ...        ...     ...             ...               ...
# 2066047  138219          1     122              20                10
# 2066048  138219          1     123              20                20
# 2066049  138219          1     124              20                30
# 2066050  138219          1     125              20                40
# 2066051  138219          1     126              20                50
#
#          ACTIVIDAD_1  ACTIVIDAD_2  ACTIVIDAD_3
# 439              711          999          999
# ...

# %%
tiempoflia = flia.groupby(['ID', 'N_MIEMBRO']).size().reset_index(name='tiempo')
tiempoflia
# Out:
#           ID  N_MIEMBRO  tiempo
# 0     100000          1      24
# 1     100001          1      15
# 2     100028          1      24
# 3     100030          2       9
# 4     100055          1      24
# ...      ...        ...     ...
# 5584  199907          2       9
# 5585  199947          4       7
# 5586  199975          2      43
# 5587  199983          9       7
# 5588  199990          2      15
#
# [5589 rows x 3 columns]

# %%
tiempoflia["tiempo"] = tiempoflia["tiempo"]*1/6  #Se transforman los bloques de 10 minutos en horas.
tiempoflia
# Out:
#           ID  N_MIEMBRO    tiempo
# 0     100000          1  4.000000
# 1     100001          1  2.500000
# 2     100028          1  4.000000
# 3     100030          2  1.500000
# 4     100055          1  4.000000
# ...      ...        ...       ...
# 5584  199907          2  1.500000
# 5585  199947          4  1.166667
# 5586  199975          2  7.166667
# 5587  199983          9  1.166667
# 5588  199990          2  2.500000
#
# [5589 rows x 3 columns]

# %%
promflia = tiempoflia["tiempo"].mean()
promflia
# Out:
# 3.8238504204687778

# %%
# Graficar los conteos
plt.figure(figsize=(18,9))
plt.scatter(tiempoflia["ID"], tiempoflia['tiempo'], marker=".", c="teal")

# Trazar la línea con el promedio
plt.axhline(y=promflia, color='red', linestyle='--',linewidth=2)
plt.text(200000,promflia + 0.5, "Promedio", color='red', fontsize=12, backgroundcolor="white")
plt.text(96000,promflia,round(promflia,2), color="red", fontsize=12)
plt.xlim(99000,plt.xlim()[1]) #Comienzo del eje X

# Configurar los títulos
plt.title("Tiempo con Familiares o Amigos", fontsize=14, y=0.95)
plt.xlabel('ID')
plt.ylabel('Horas', fontsize=12)

# Mostrar el gráfico
plt.show()

# %%
#Hacer Deporte 
deporte = data.loc[(data[["ACTIVIDAD_1","ACTIVIDAD_2","ACTIVIDAD_3"]] == 74).any(axis=1)]
deporte
# Out:
#              ID  N_MIEMBRO  N_FILA  ACTIVIDAD_HORA  ACTIVIDAD_MINUTO  \
# 812      164184          2      97              16                 0
# 813      164184          2      98              16                10
# 814      164184          2      99              16                20
# 815      164184          2     100              16                30
# 816      164184          2     101              16                40
# ...         ...        ...     ...             ...               ...
# 2064181  155567          1     116              19                10
# 2064182  155567          1     117              19                20
# 2064183  155567          1     118              19                30
# 2064184  155567          1     119              19                40
# 2064185  155567          1     120              19                50
#
#          ACTIVIDAD_1  ACTIVIDAD_2  ACTIVIDAD_3
# 812               74          999          999
# ...

# %%
tiempodeporte = deporte.groupby(['ID', 'N_MIEMBRO']).size().reset_index(name='tiempo')
tiempodeporte
# Out:
#           ID  N_MIEMBRO  tiempo
# 0     100030          2       6
# 1     100110          1       1
# 2     100133          1       6
# 3     100262          1       8
# 4     100276          1      10
# ...      ...        ...     ...
# 2390  199817          1      12
# 2391  199823          1      13
# 2392  199838          1       7
# 2393  199858          1      18
# 2394  199899          1      12
#
# [2395 rows x 3 columns]

# %%
tiempodeporte["tiempo"] = tiempodeporte["tiempo"]*1/6  #Se transforman los bloques de 10 minutos en horas.
tiempodeporte
# Out:
#           ID  N_MIEMBRO    tiempo
# 0     100030          2  1.000000
# 1     100110          1  0.166667
# 2     100133          1  1.000000
# 3     100262          1  1.333333
# 4     100276          1  1.666667
# ...      ...        ...       ...
# 2390  199817          1  2.000000
# 2391  199823          1  2.166667
# 2392  199838          1  1.166667
# 2393  199858          1  3.000000
# 2394  199899          1  2.000000
#
# [2395 rows x 3 columns]

# %%
promdeporte = tiempodeporte["tiempo"].mean()
promdeporte
# Out:
# 1.8189283228949198

# %%
# Graficar los conteos
plt.figure(figsize=(18,8))
plt.scatter(tiempodeporte["ID"], tiempodeporte['tiempo'], marker=".", c="indigo")

# Trazar la línea con el promedio
plt.axhline(y=promdeporte, color='red', linestyle='--',linewidth=2)
plt.text(200000,promdeporte + 0.5, "Promedio", color='red', fontsize=12, backgroundcolor="white")
plt.text(96000,promdeporte - 0.3,round(promdeporte,2), color="red", fontsize=12)
plt.xlim(99000,plt.xlim()[1]) #Comienzo del eje X

# Configurar los títulos
plt.title("Tiempo haciendo Deporte", fontsize=14, y=0.95)
plt.xlabel('ID')
plt.ylabel('Horas', fontsize=12)

# Mostrar el gráfico
plt.show()

# %%
#Viajar al Trabajo 
viajar = data.loc[(data[["ACTIVIDAD_1","ACTIVIDAD_2","ACTIVIDAD_3"]] == 14).any(axis=1)]
viajar
# Out:
#              ID  N_MIEMBRO  N_FILA  ACTIVIDAD_HORA  ACTIVIDAD_MINUTO  \
# 87       182814          2      58               9                30
# 88       182814          2      59               9                40
# 97       181931          1      49               8                 0
# 98       181931          1      50               8                10
# 99       181931          1      51               8                20
# ...         ...        ...     ...             ...               ...
# 2066357  174993          2      96              15                50
# 2066358  174993          2      97              16                 0
# 2066359  174993          2      98              16                10
# 2066360  174993          2      99              16                20
# 2066361  174993          2     100              16                30
#
#          ACTIVIDAD_1  ACTIVIDAD_2  ACTIVIDAD_3
# 87                14          999          999
# ...

# %%
tiempoviaje = viajar.groupby(['ID', 'N_MIEMBRO']).size().reset_index(name='tiempo')
tiempoviaje
# Out:
#           ID  N_MIEMBRO  tiempo
# 0     100012          1       6
# 1     100038          1       6
# 2     100057          3       2
# 3     100110          1       5
# 4     100121          1       6
# ...      ...        ...     ...
# 4468  199838          1       5
# 4469  199858          1       1
# 4470  199861          1       6
# 4471  199871          2      12
# 4472  199983          9      10
#
# [4473 rows x 3 columns]

# %%
tiempoviaje["tiempo"] = tiempoviaje["tiempo"]*1/6  #Se transforman los bloques de 10 minutos en horas.
tiempoviaje
# Out:
#           ID  N_MIEMBRO    tiempo
# 0     100012          1  1.000000
# 1     100038          1  1.000000
# 2     100057          3  0.333333
# 3     100110          1  0.833333
# 4     100121          1  1.000000
# ...      ...        ...       ...
# 4468  199838          1  0.833333
# 4469  199858          1  0.166667
# 4470  199861          1  1.000000
# 4471  199871          2  2.000000
# 4472  199983          9  1.666667
#
# [4473 rows x 3 columns]

# %%
promviaje = tiempoviaje["tiempo"].mean()
promviaje
# Out:
# 1.123146285118116

# %%
# Graficar los conteos
plt.figure(figsize=(18,6))
plt.scatter(tiempoviaje["ID"], tiempoviaje['tiempo'], marker=".", c="yellowgreen")

# Trazar la línea con el promedio
plt.axhline(y=promviaje, color='red', linestyle='--',linewidth=2)
plt.text(200000,promviaje + 0.5, "Promedio", color='red', fontsize=12, backgroundcolor="white")
plt.text(96000,promviaje - 0.3,round(promviaje,2), color="red", fontsize=12)
plt.xlim(99000,plt.xlim()[1]) #Comienzo del eje X

# Configurar los títulos
plt.title("Viajar al Trabajo", fontsize=14, y=0.90)
plt.xlabel('ID')
plt.ylabel('Horas', fontsize=12)

# Mostrar el gráfico
plt.show()
